# %%
# First attempt at feature extraction
# Leads to an error, can you tell why?

import pandas as pd
import numpy as np

df = pd.read_csv('tweets.csv')
target = df['is_there_an_emotion_directed_at_a_brand_or_product']
text = df['tweet_text']

from sklearn.feature_extraction.text import CountVectorizer

count_vect=CountVectorizer()

# %%
# sets up all words as columns in a 2D data set
# This one will blow up since there are empty rows
# count_vect.fit(text)

# clean up and extract feature again
fixed_text = text[pd.notnull(text)]
fixed_target = target[pd.notnull(text)]
count_vect.fit(fixed_text)
# Out:
# CountVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
# It is case sensitive
print(count_vect.vocabulary_.get(u'The'))
# Out:
# None

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-612fa13e9a96> in <module>()
# ----> 1 print(count_vect.to_array())
#
# AttributeError: 'CountVectorizer' object has no attribute 'to_array'

# %%
# shows all the fits
counts = count_vect.transform(fixed_text)
# shows all entries but omits the features will zero occurence
print(counts)
# Out:
#   (0, 168)	1
#   (0, 430)	1
#   (0, 774)	2
#   (0, 2291)	1
#   (0, 3981)	1
#   (0, 4210)	1
#   (0, 4573)	1
#   (0, 4610)	1
#   (0, 5766)	1
#   (0, 6478)	1
#   (0, 7232)	1
#   (0, 8076)	1
#   (0, 8323)	1
#   (0, 8702)	1
#   (0, 8920)	1
#   (0, 9062)	1
#   (0, 9303)	1
#   (0, 9373)	1
#   (1, 313)	1
#   (1, 527)	1
#   (1, 644)	1
#   (1, 677)	1
#   (1, 774)	1
#   (1, 876)	1
#   (1, 2386)	1
#   :	:
#   (9090, 5801)	1
#   (9090, 5967)	1
#   (9090, 7903)	1
#   (9090, 8323)	1
#   (9090, 8562)	1
#   (9090, 8578)	1
#   (9090, 8602)	1
#   (9090, 8616)	1
#   (9090, 8666)	1
#   (9090, 9158)	1
#   (9090, 9357)	1
#   (9090, 9371)	1
#   (9090, 9402)	1
#   (9090, 9623)	1
#   (9091, 774)	1
#   (9091, 1618)	1
#   (9091, 3741)	1
#   (9091, 4374)	1
#   (9091, 5057)	1
#   (9091, 5435)	1
#   (9091, 5974)	1
#   (9091, 7294)	1
#   (9091, 8323)	1
#   (9091, 8539)	1
#   (9091, 9701)	1

# %%
# dimensions of matrix
#   rows and columns
#   seems like we have more columns than rows
print(counts.shape)
# Out:
# (9092, 9706)

# %%
# Print feature number #774
print(count_vect.get_feature_names()[774])
# Out:
# at

# %%
# Printing all features
print(count_vect.vocabulary_)
# Out:
# {u'unscientific': 9041, u'hordes': 4175, u'pickmeupanipad2': 6384, u'yellow': 9607, u'four': 3434, u'prices': 6651, u'woods': 9500, u'hanging': 3940, u'16mins': 70, u'looking': 5142, u'html5': 4215, u'gad': 3543, u'eligible': 2846, u'gadgetoverload': 3546, u'insertion': 4461, u'lori': 5153, u'sxswdad': 8339, u'lord': 5151, u'newmusic': 5808, u'dynamic': 2743, u'bergstrom': 1065, u'dell': 2351, u'rancewilemon': 6891, u'leisurely': 4984, u'bringing': 1305, u'basics': 971, u'prize': 6674, u'customizable': 2213, u'wednesday': 9355, u'oooh': 6027, u'debuting': 2305, u'commented': 1839, u'smscifi': 7824, u'tired': 8686, u'miller': 5505, u'cpmpetition': 2094, u'pulse': 6771, u'270': 116, u'elegant': 2841, u'second': 7469, u'tether': 8540, u'penasaran': 6300, u'errors': 2962, u'unlisted': 9022, u'roddy': 7262, u'thunder': 8644, u'fingers': 3286, u'designing': 2392, u'succumb': 8210, u'reword_app': 7186, u'hero': 4054, u'dahl': 2233, u'reporter': 7104, u'freebeernear': 3455, u'leaning': 4957,
# ...

# %%
# transforming words to corresponding features and occurence
print(count_vect.transform(['love my iphone']))
# Out:
#   (0, 4573)	1
#   (0, 5169)	1
#   (0, 5699)	1
